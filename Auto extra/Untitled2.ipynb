# %%
import os
import cv2
import numpy as np

# Define paths
train_path = './Users/somay/Downloads/Autonomos/Train'
test_path = './Users/somay/Downloads/Autonomos/Test'

# Parameters
IMG_HEIGHT, IMG_WIDTH = 30, 30

def load_images_from_folder(folder):
    images = []
    labels = []
    for class_id in range(43):  # There are 43 classes
        class_path = os.path.join(folder, str(class_id))
        print(f"Checking path: {class_path}")  # Debug statement
        if not os.path.exists(class_path):
            print(f"Path does not exist: {class_path}")  # Debug statement
            continue
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            img = cv2.imread(img_path)
            if img is not None:
                img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
                images.append(img)
                labels.append(class_id)
    return np.array(images), np.array(labels)

# Load and preprocess training images
X_train, y_train = load_images_from_folder(train_path)
X_train = X_train / 255.0

# Print the number of images loaded
print(f"Number of training images: {len(X_train)}")
print(f"Number of training labels: {len(y_train)}")

# Check if any images are loaded
if len(X_train) == 0 or len(y_train) == 0:
    raise ValueError("No training data found. Please check the training data directory.")

# Split the training data into training and validation sets
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Load and preprocess test images
X_test, y_test = load_images_from_folder(test_path)
X_test = X_test / 255.0

# Verify shapes of the data
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Checking path: ./Users/somay/Downloads/Autonomos/Train\0
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\0
# Checking path: ./Users/somay/Downloads/Autonomos/Train\1
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\1
# Checking path: ./Users/somay/Downloads/Autonomos/Train\2
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\2
# Checking path: ./Users/somay/Downloads/Autonomos/Train\3
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\3
# Checking path: ./Users/somay/Downloads/Autonomos/Train\4
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\4
# Checking path: ./Users/somay/Downloads/Autonomos/Train\5
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\5
# Checking path: ./Users/somay/Downloads/Autonomos/Train\6
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\6
# Checking path: ./Users/somay/Downloads/Autonomos/Train\7
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\7
# Checking path: ./Users/somay/Downloads/Autonomos/Train\8
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\8
# Checking path: ./Users/somay/Downloads/Autonomos/Train\9
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\9
# Checking path: ./Users/somay/Downloads/Autonomos/Train\10
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\10
# Checking path: ./Users/somay/Downloads/Autonomos/Train\11
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\11
# Checking path: ./Users/somay/Downloads/Autonomos/Train\12
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\12
# Checking path: ./Users/somay/Downloads/Autonomos/Train\13
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\13
# Checking path: ./Users/somay/Downloads/Autonomos/Train\14
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\14
# Checking path: ./Users/somay/Downloads/Autonomos/Train\15
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\15
# Checking path: ./Users/somay/Downloads/Autonomos/Train\16
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\16
# Checking path: ./Users/somay/Downloads/Autonomos/Train\17
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\17
# Checking path: ./Users/somay/Downloads/Autonomos/Train\18
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\18
# Checking path: ./Users/somay/Downloads/Autonomos/Train\19
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\19
# Checking path: ./Users/somay/Downloads/Autonomos/Train\20
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\20
# Checking path: ./Users/somay/Downloads/Autonomos/Train\21
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\21
# Checking path: ./Users/somay/Downloads/Autonomos/Train\22
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\22
# Checking path: ./Users/somay/Downloads/Autonomos/Train\23
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\23
# Checking path: ./Users/somay/Downloads/Autonomos/Train\24
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\24
# Checking path: ./Users/somay/Downloads/Autonomos/Train\25
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\25
# Checking path: ./Users/somay/Downloads/Autonomos/Train\26
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\26
# Checking path: ./Users/somay/Downloads/Autonomos/Train\27
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\27
# Checking path: ./Users/somay/Downloads/Autonomos/Train\28
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\28
# Checking path: ./Users/somay/Downloads/Autonomos/Train\29
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\29
# Checking path: ./Users/somay/Downloads/Autonomos/Train\30
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\30
# Checking path: ./Users/somay/Downloads/Autonomos/Train\31
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\31
# Checking path: ./Users/somay/Downloads/Autonomos/Train\32
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\32
# Checking path: ./Users/somay/Downloads/Autonomos/Train\33
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\33
# Checking path: ./Users/somay/Downloads/Autonomos/Train\34
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\34
# Checking path: ./Users/somay/Downloads/Autonomos/Train\35
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\35
# Checking path: ./Users/somay/Downloads/Autonomos/Train\36
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\36
# Checking path: ./Users/somay/Downloads/Autonomos/Train\37
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\37
# Checking path: ./Users/somay/Downloads/Autonomos/Train\38
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\38
# Checking path: ./Users/somay/Downloads/Autonomos/Train\39
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\39
# Checking path: ./Users/somay/Downloads/Autonomos/Train\40
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\40
# Checking path: ./Users/somay/Downloads/Autonomos/Train\41
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\41
# Checking path: ./Users/somay/Downloads/Autonomos/Train\42
# Path does not exist: ./Users/somay/Downloads/Autonomos/Train\42
# Number of training images: 0
# Number of training labels: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 40
#      38 # Check if any images are loaded
#      39 if len(X_train) == 0 or len(y_train) == 0:
# ---> 40     raise ValueError("No training data found. Please check the training data directory.")
#      42 # Split the training data into training and validation sets
#      43 from sklearn.model_selection import train_test_split
#
# ValueError: No training data found. Please check the training data directory.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Input(shape=(30, 30, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(43, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 43)             │         5,547 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 164,459 (642.42 KB)
#  Trainable params: 164,459 (642.42 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=10, validation_data=(X_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 history = model.fit(X_train, y_train, epochs=10, validation_split=0.2)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_slicing.py:492, in train_validation_split(arrays, validation_split)
#     489 split_at = int(math.floor(batch_dim * (1.0 - validation_split)))
#     491 if split_at == 0 or split_at == batch_dim:
# --> 492     raise ValueError(
#     493         f"Training data contains {batch_dim} samples, which is not "
#     494         "sufficient to split it into a validation and training set as "
#     495         f"specified by `validation_split={validation_split}`. Either "
#     496         "provide more data, or a different value for the "
#     497         "`validation_split` argument."
#     498     )
#     500 def _split(t, start, end):
#     501     if t is None:
#
# ValueError: Training data contains 0 samples, which is not sufficient to split it into a validation and training set as specified by `validation_split=0.2`. Either provide more data, or a different value for the `validation_split` argument.
